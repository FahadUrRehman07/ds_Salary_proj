# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("glassdoor_jobs.csv")

# %%
df.shape
# Out:
# (956, 15)

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    Unnamed: 0                  Job Title               Salary Estimate  \
# 0           0             Data Scientist    $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist   $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist    $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist    $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist   $86K-$143K (Glassdoor est.)
# 5           5             Data Scientist   $71K-$119K (Glassdoor est.)
# 6           6             Data Scientist    $54K-$93K (Glassdoor est.)
# 7           7             Data Scientist   $86K-$142K (Glassdoor est.)
# 8           8         Research Scientist    $38K-$84K (Glassdoor est.)
# 9           9             Data Scientist  $120K-$160K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
# 5                               CyrusOne\n3.4       Dallas, TX
# 6                     ClearOne Advantage\n4.1    Baltimore, MD
# 7                             Logic20/20\n3.8     San Jose, CA
# 8              Rochester Regional Health\n3.3    Rochester, NY
# 9                               <intent>\n4.6     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
# 5      Dallas, TX    201 to 500 employees     2000    Company - Public
# 6   Baltimore, MD   501 to 1000 employees     2008   Company - Private
# 7     Seattle, WA    201 to 500 employees     2005   Company - Private
# 8   Rochester, NY        10000+ employees     2014            Hospital
# 9    New York, NY     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors
# 0                                                 -1
# 1                                                 -1
# 2                                                 -1
# 3  Oak Ridge National Laboratory, National Renewa...
# 4               Commerce Signals, Cardlytics, Yodlee
# 5                  Digital Realty, CoreSite, Equinix
# 6                                                 -1
# 7                                                 -1
# 8                                                 -1
# 9                          Clicktripz, SmarterTravel

# %% [markdown]
# #### by looking into the scraped data we will do the following tasks.
#
# # Tasks List:
#
# 1. Salary Parsing.
# 2. Company Name text only
# 3. State of Field.
# 4. Age of Company.
# 5. Parsing of job description (python, etc.)

# %% [markdown]
# # 1. Salary Parsing

# %% [markdown]
# Removing the -1 in the salary estimate column

# %%
df = df[df['Salary Estimate']!= '-1']
df.head(10)
# Out:
#    Unnamed: 0                  Job Title               Salary Estimate  \
# 0           0             Data Scientist    $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist   $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist    $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist    $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist   $86K-$143K (Glassdoor est.)
# 5           5             Data Scientist   $71K-$119K (Glassdoor est.)
# 6           6             Data Scientist    $54K-$93K (Glassdoor est.)
# 7           7             Data Scientist   $86K-$142K (Glassdoor est.)
# 8           8         Research Scientist    $38K-$84K (Glassdoor est.)
# 9           9             Data Scientist  $120K-$160K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
# 5                               CyrusOne\n3.4       Dallas, TX
# 6                     ClearOne Advantage\n4.1    Baltimore, MD
# 7                             Logic20/20\n3.8     San Jose, CA
# 8              Rochester Regional Health\n3.3    Rochester, NY
# 9                               <intent>\n4.6     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
# 5      Dallas, TX    201 to 500 employees     2000    Company - Public
# 6   Baltimore, MD   501 to 1000 employees     2008   Company - Private
# 7     Seattle, WA    201 to 500 employees     2005   Company - Private
# 8   Rochester, NY        10000+ employees     2014            Hospital
# 9    New York, NY     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors
# 0                                                 -1
# 1                                                 -1
# 2                                                 -1
# 3  Oak Ridge National Laboratory, National Renewa...
# 4               Commerce Signals, Cardlytics, Yodlee
# 5                  Digital Realty, CoreSite, Equinix
# 6                                                 -1
# 7                                                 -1
# 8                                                 -1
# 9                          Clicktripz, SmarterTravel

# %% [markdown]
# ### Removing the glassdoor est text in the salary column:

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.split('(')[0])

# %%
df.head(10)
# Out:
#    Unnamed: 0                  Job Title Salary Estimate  \
# 0           0             Data Scientist      $53K-$91K
# 1           1  Healthcare Data Scientist     $63K-$112K
# 2           2             Data Scientist      $80K-$90K
# 3           3             Data Scientist      $56K-$97K
# 4           4             Data Scientist     $86K-$143K
# 5           5             Data Scientist     $71K-$119K
# 6           6             Data Scientist      $54K-$93K
# 7           7             Data Scientist     $86K-$142K
# 8           8         Research Scientist      $38K-$84K
# 9           9             Data Scientist    $120K-$160K
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
# 5                               CyrusOne\n3.4       Dallas, TX
# 6                     ClearOne Advantage\n4.1    Baltimore, MD
# 7                             Logic20/20\n3.8     San Jose, CA
# 8              Rochester Regional Health\n3.3    Rochester, NY
# 9                               <intent>\n4.6     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
# 5      Dallas, TX    201 to 500 employees     2000    Company - Public
# 6   Baltimore, MD   501 to 1000 employees     2008   Company - Private
# 7     Seattle, WA    201 to 500 employees     2005   Company - Private
# 8   Rochester, NY        10000+ employees     2014            Hospital
# 9    New York, NY     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors
# 0                                                 -1
# 1                                                 -1
# 2                                                 -1
# 3  Oak Ridge National Laboratory, National Renewa...
# 4               Commerce Signals, Cardlytics, Yodlee
# 5                  Digital Realty, CoreSite, Equinix
# 6                                                 -1
# 7                                                 -1
# 8                                                 -1
# 9                          Clicktripz, SmarterTravel

# %% [markdown]
# ### Removing the k and $ sign from the Salary Estimate

# %%
# Removing the k and $ sign from the salary column so that 
#we can predict or do analysis on numbers

df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.replace('K','').replace('$',''))
df.head(10)
# Out:
#    Unnamed: 0                  Job Title Salary Estimate  \
# 0           0             Data Scientist          53-91
# 1           1  Healthcare Data Scientist         63-112
# 2           2             Data Scientist          80-90
# 3           3             Data Scientist          56-97
# 4           4             Data Scientist         86-143
# 5           5             Data Scientist         71-119
# 6           6             Data Scientist          54-93
# 7           7             Data Scientist         86-142
# 8           8         Research Scientist          38-84
# 9           9             Data Scientist        120-160
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
# 5                               CyrusOne\n3.4       Dallas, TX
# 6                     ClearOne Advantage\n4.1    Baltimore, MD
# 7                             Logic20/20\n3.8     San Jose, CA
# 8              Rochester Regional Health\n3.3    Rochester, NY
# 9                               <intent>\n4.6     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
# 5      Dallas, TX    201 to 500 employees     2000    Company - Public
# 6   Baltimore, MD   501 to 1000 employees     2008   Company - Private
# 7     Seattle, WA    201 to 500 employees     2005   Company - Private
# 8   Rochester, NY        10000+ employees     2014            Hospital
# 9    New York, NY     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors
# 0                                                 -1
# 1                                                 -1
# 2                                                 -1
# 3  Oak Ridge National Laboratory, National Renewa...
# 4               Commerce Signals, Cardlytics, Yodlee
# 5                  Digital Realty, CoreSite, Equinix
# 6                                                 -1
# 7                                                 -1
# 8                                                 -1
# 9                          Clicktripz, SmarterTravel

# %% [markdown]
# The K and $ sign are removed from the column.<br>
# Its a range of numbers we have to convert it into a single number so it can be used for analysis and prediction.

# %% [markdown]
# ### Removing Per hour & Employee provided salary text in Salary Estimated Column

# %%
df['PerHour'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['Employee'] = df['Salary Estimate'].apply(lambda x: 1 if 'employee provided salary:' in x.lower() else 0)

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.lower().replace('per hour', ''))
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.lower().replace('employer provided salary:', ''))

# %%
pd.set_option('display.max_rows', 10)
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#     Salary Estimate                                    Job Description  \
# 0            53-91   Data Scientist\nLocation: Albuquerque, NM\nEdu...
# 1           63-112   What You Will Do:\n\nI. General Summary\n\nThe...
# 2            80-90   KnowBe4, Inc. is a high growth information sec...
# 3            56-97   *Organization and Job ID**\nJob ID: 310709\n\n...
# 4           86-143   Data Scientist\nAffinity Solutions / Marketing...
# ..              ...                                                ...
# 950         58-111   Site Name: USA - Massachusetts - Cambridge\nPo...
# 951         72-133   THE CHALLENGE\nEventbrite has a world-class da...
# 952          56-91   The Auton Lab at Carnegie Mellon University is...
# 953         95-160   Data Science ManagerResponsibilities:\n\nOvers...
# 955         61-126   Returning Candidate? Log back in to the Career...
#
#      Rating                                Company Name         Location  \
# 0       3.8                      Tecolote Research\n3.8  Albuquerque, NM
# 1       3.4  University of Maryland Medical System\n3.4    Linthicum, MD
# 2       4.8                                KnowBe4\n4.8   Clearwater, FL
# 3       3.8                                   PNNL\n3.8     Richland, WA
# 4       2.9                     Affinity Solutions\n2.9     New York, NY
# ..      ...                                         ...              ...
# 950     3.9                                    GSK\n3.9    Cambridge, MA
# 951     4.4                             Eventbrite\n4.4    Nashville, TN
# 952     2.6         Software Engineering Institute\n2.6   Pittsburgh, PA
# 953     3.2                           Numeric, LLC\n3.2    Allentown, PA
# 955     3.6           Riverside Research Institute\n3.6  Beavercreek, OH
#
#                   Headquarters                    Size  Founded  \
# 0                   Goleta, CA   501 to 1000 employees     1973
# 1                Baltimore, MD        10000+ employees     1984
# 2               Clearwater, FL   501 to 1000 employees     2010
# 3                 Richland, WA  1001 to 5000 employees     1965
# 4                 New York, NY     51 to 200 employees     1998
# ..                         ...                     ...      ...
# 950  Brentford, United Kingdom        10000+ employees     1830
# 951          San Francisco, CA  1001 to 5000 employees     2006
# 952             Pittsburgh, PA   501 to 1000 employees     1984
# 953            Chadds Ford, PA       1 to 50 employees       -1
# 955              Arlington, VA   501 to 1000 employees     1967
#
#           Type of ownership                          Industry  \
# 0         Company - Private               Aerospace & Defense
# 1        Other Organization  Health Care Services & Hospitals
# 2         Company - Private                 Security Services
# 3                Government                            Energy
# 4         Company - Private           Advertising & Marketing
# ..                      ...                               ...
# 950        Company - Public         Biotech & Pharmaceuticals
# 951        Company - Public                          Internet
# 952    College / University           Colleges & Universities
# 953       Company - Private            Staffing & Outsourcing
# 955  Nonprofit Organization                  Federal Agencies
#
#                            Sector                           Revenue  \
# 0             Aerospace & Defense         $50 to $100 million (USD)
# 1                     Health Care            $2 to $5 billion (USD)
# 2               Business Services        $100 to $500 million (USD)
# 3    Oil, Gas, Energy & Utilities  $500 million to $1 billion (USD)
# 4               Business Services          Unknown / Non-Applicable
# ..                            ...                               ...
# 950     Biotech & Pharmaceuticals                $10+ billion (USD)
# 951        Information Technology        $100 to $500 million (USD)
# 952                     Education          Unknown / Non-Applicable
# 953             Business Services           $5 to $10 million (USD)
# 955                    Government         $50 to $100 million (USD)
#
#                                            Competitors  PerHour  Employee
# 0                                                   -1        0         0
# 1                                                   -1        0         0
# 2                                                   -1        0         0
# 3    Oak Ridge National Laboratory, National Renewa...        0         0
# 4                 Commerce Signals, Cardlytics, Yodlee        0         0
# ..                                                 ...      ...       ...
# 950                         Pfizer, AstraZeneca, Merck        0         0
# 951                    See Tickets, TicketWeb, Vendini        0         0
# 952                                                 -1        0         0
# 953                                                 -1        0         0
# 955                                                 -1        0         0
#
# [742 rows x 17 columns]

# %% [markdown]
# Now the per hour text and employee provided salary text is removed from the salary estimated column.<br>
# Only the integer value is remained but there still a problem that the integer is in interval and we have to convert into a single integer.
# ................................................................................................................................................................................................................................................................

# %% [markdown]
# ### Splitting the Salary estimated column

# %% [markdown]
# - The first will be the minimum salary.<br>
# - The second will be the Maximumn Salary.

# %%
df['Min_Salary'] = df['Salary Estimate'].apply(lambda x: int(x.split('-')[0]))

# %%
df['Max_Salary'] = df['Salary Estimate'].apply(lambda x: int(x.split('-')[1]))

# %% [markdown]
# - <b> Now two columns are created Min and Max salary.</b><br>
# To get the single integer in Salary Estimate column we will take average of these two columns

# %%
df['Salary Estimate']= (df['Min_Salary'] + df['Max_Salary'])/2

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title  Salary Estimate  \
# 0           0             Data Scientist             72.0
# 1           1  Healthcare Data Scientist             87.5
# 2           2             Data Scientist             85.0
# 3           3             Data Scientist             76.5
# 4           4             Data Scientist            114.5
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
#
#    Min_Salary  Max_Salary
# 0          53          91
# 1          63         112
# 2          80          90
# 3          56          97
# 4          86         143

# %% [markdown]
# - Now the Salary Estimate column is completely clean and ready to use.<br>
# NOTE: The datatype of values is float and if for some reason you want to convert in into integer datatype use the following line of code.
#
# ```
# df['Salary Estimate']= (df['Min_Salary'] + df['Max_Salary'])//2
# ```

# %%
#df.drop(['Min_Salary','Max_Salary'] , axis =1)

# %% [markdown]
# ## 2.Cleaning Company Name Column

# %%
df.head(10)
# Out:
#    Unnamed: 0                  Job Title  Salary Estimate  \
# 0           0             Data Scientist             72.0
# 1           1  Healthcare Data Scientist             87.5
# 2           2             Data Scientist             85.0
# 3           3             Data Scientist             76.5
# 4           4             Data Scientist            114.5
# 5           5             Data Scientist             95.0
# 6           6             Data Scientist             73.5
# 7           7             Data Scientist            114.0
# 8           8         Research Scientist             61.0
# 9           9             Data Scientist            140.0
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
# 5                               CyrusOne\n3.4       Dallas, TX
# 6                     ClearOne Advantage\n4.1    Baltimore, MD
# 7                             Logic20/20\n3.8     San Jose, CA
# 8              Rochester Regional Health\n3.3    Rochester, NY
# 9                               <intent>\n4.6     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
# 5      Dallas, TX    201 to 500 employees     2000    Company - Public
# 6   Baltimore, MD   501 to 1000 employees     2008   Company - Private
# 7     Seattle, WA    201 to 500 employees     2005   Company - Private
# 8   Rochester, NY        10000+ employees     2014            Hospital
# 9    New York, NY     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
# 5                  Digital Realty, CoreSite, Equinix        0         0
# 6                                                 -1        0         0
# 7                                                 -1        0         0
# 8                                                 -1        0         0
# 9                          Clicktripz, SmarterTravel        0         0
#
#    Min_Salary  Max_Salary
# 0          53          91
# 1          63         112
# 2          80          90
# 3          56          97
# 4          86         143
# 5          71         119
# 6          54          93
# 7          86         142
# 8          38          84
# 9         120         160

# %%
df['Company Name'] = df.apply(lambda x: x['Company Name'] if x['Rating']<0 else x['Company Name'][:-1], axis = 1)

# %%
df = df.drop(['Company-Name','CompanyName'], axis =1)
df.head(10)
# Out:
#    Unnamed: 0                  Job Title  Salary Estimate  \
# 0           0             Data Scientist             72.0
# 1           1  Healthcare Data Scientist             87.5
# 2           2             Data Scientist             85.0
# 3           3             Data Scientist             76.5
# 4           4             Data Scientist            114.5
# 5           5             Data Scientist             95.0
# 6           6             Data Scientist             73.5
# 7           7             Data Scientist            114.0
# 8           8         Research Scientist             61.0
# 9           9             Data Scientist            140.0
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                                 Company Name         Location    Headquarters  \
# 0                      Tecolote Research\n3.  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System\n3.    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4\n4.   Clearwater, FL  Clearwater, FL
# 3                                   PNNL\n3.     Richland, WA    Richland, WA
# 4                     Affinity Solutions\n2.     New York, NY    New York, NY
# 5                               CyrusOne\n3.       Dallas, TX      Dallas, TX
# 6                     ClearOne Advantage\n4.    Baltimore, MD   Baltimore, MD
# 7                             Logic20/20\n3.     San Jose, CA     Seattle, WA
# 8              Rochester Regional Health\n3.    Rochester, NY   Rochester, NY
# 9                               <intent>\n4.     New York, NY    New York, NY
#
#                      Size  Founded   Type of ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2   501 to 1000 employees     2010   Company - Private
# 3  1001 to 5000 employees     1965          Government
# 4     51 to 200 employees     1998   Company - Private
# 5    201 to 500 employees     2000    Company - Public
# 6   501 to 1000 employees     2008   Company - Private
# 7    201 to 500 employees     2005   Company - Private
# 8        10000+ employees     2014            Hospital
# 9     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
# 5                  Digital Realty, CoreSite, Equinix        0         0
# 6                                                 -1        0         0
# 7                                                 -1        0         0
# 8                                                 -1        0         0
# 9                          Clicktripz, SmarterTravel        0         0
#
#    Min_Salary  Max_Salary
# 0          53          91
# 1          63         112
# 2          80          90
# 3          56          97
# 4          86         143
# 5          71         119
# 6          54          93
# 7          86         142
# 8          38          84
# 9         120         160

# %%
df['Company Name']= df['Company Name'].apply(lambda x: x.split('\n')[0])

# %%
df = df.drop(['CompanyName'], axis =1)
df.head(10)
# Out:
#    Unnamed: 0                  Job Title  Salary Estimate  \
# 0           0             Data Scientist             72.0
# 1           1  Healthcare Data Scientist             87.5
# 2           2             Data Scientist             85.0
# 3           3             Data Scientist             76.5
# 4           4             Data Scientist            114.5
# 5           5             Data Scientist             95.0
# 6           6             Data Scientist             73.5
# 7           7             Data Scientist            114.0
# 8           8         Research Scientist             61.0
# 9           9             Data Scientist            140.0
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# 3                                   PNNL     Richland, WA    Richland, WA
# 4                     Affinity Solutions     New York, NY    New York, NY
# 5                               CyrusOne       Dallas, TX      Dallas, TX
# 6                     ClearOne Advantage    Baltimore, MD   Baltimore, MD
# 7                             Logic20/20     San Jose, CA     Seattle, WA
# 8              Rochester Regional Health    Rochester, NY   Rochester, NY
# 9                               <intent>     New York, NY    New York, NY
#
#                      Size  Founded   Type of ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2   501 to 1000 employees     2010   Company - Private
# 3  1001 to 5000 employees     1965          Government
# 4     51 to 200 employees     1998   Company - Private
# 5    201 to 500 employees     2000    Company - Public
# 6   501 to 1000 employees     2008   Company - Private
# 7    201 to 500 employees     2005   Company - Private
# 8        10000+ employees     2014            Hospital
# 9     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
# 5                  Digital Realty, CoreSite, Equinix        0         0
# 6                                                 -1        0         0
# 7                                                 -1        0         0
# 8                                                 -1        0         0
# 9                          Clicktripz, SmarterTravel        0         0
#
#    Min_Salary  Max_Salary
# 0          53          91
# 1          63         112
# 2          80          90
# 3          56          97
# 4          86         143
# 5          71         119
# 6          54          93
# 7          86         142
# 8          38          84
# 9         120         160

# %% [markdown]
# <b>Now the Company Name column is cleaned and ready to use for EDA</b>

# %% [markdown]
# ## State of Field Column Cleaning

# %% [markdown]
# We can create the state column from the location column

# %%
df['State'] = df.Location.apply(lambda x: x.split(',')[1])

# %%
df= df.drop(['States'], axis = 1)
df.head()
# Out:
#    Unnamed: 0                  Job Title  Salary Estimate  \
# 0           0             Data Scientist             72.0
# 1           1  Healthcare Data Scientist             87.5
# 2           2             Data Scientist             85.0
# 3           3             Data Scientist             76.5
# 4           4             Data Scientist            114.5
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# 3                                   PNNL     Richland, WA    Richland, WA
# 4                     Affinity Solutions     New York, NY    New York, NY
#
#                      Size  Founded   Type of ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2   501 to 1000 employees     2010   Company - Private
# 3  1001 to 5000 employees     1965          Government
# 4     51 to 200 employees     1998   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
#
#    Min_Salary  Max_Salary State
# 0          53          91    NM
# 1          63         112    MD
# 2          80          90    FL
# 3          56          97    WA
# 4          86         143    NY

# %% [markdown]
# #### Lets see if the location & Headquarter is same

# %%
df['Same State'] = df.apply(lambda x: 1 if x.Location==x.Headquarters else 0, axis =1)
df.head()
# Out:
#    Unnamed: 0                  Job Title  Salary Estimate  \
# 0           0             Data Scientist             72.0
# 1           1  Healthcare Data Scientist             87.5
# 2           2             Data Scientist             85.0
# 3           3             Data Scientist             76.5
# 4           4             Data Scientist            114.5
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# 3                                   PNNL     Richland, WA    Richland, WA
# 4                     Affinity Solutions     New York, NY    New York, NY
#
#                      Size  Founded   Type of ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2   501 to 1000 employees     2010   Company - Private
# 3  1001 to 5000 employees     1965          Government
# 4     51 to 200 employees     1998   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
#
#    Min_Salary  Max_Salary State  Same State
# 0          53          91    NM           0
# 1          63         112    MD           0
# 2          80          90    FL           1
# 3          56          97    WA           1
# 4          86         143    NY           1

# %% [markdown]
# ## Age of Company

# %%
df['Age'] = df['Founded'].apply(lambda x: x if x<1 else 2023-x)

# %%
df.head(10)
# Out:
#    Unnamed: 0                  Job Title  Salary Estimate  \
# 0           0             Data Scientist             72.0
# 1           1  Healthcare Data Scientist             87.5
# 2           2             Data Scientist             85.0
# 3           3             Data Scientist             76.5
# 4           4             Data Scientist            114.5
# 5           5             Data Scientist             95.0
# 6           6             Data Scientist             73.5
# 7           7             Data Scientist            114.0
# 8           8         Research Scientist             61.0
# 9           9             Data Scientist            140.0
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# 3                                   PNNL     Richland, WA    Richland, WA
# 4                     Affinity Solutions     New York, NY    New York, NY
# 5                               CyrusOne       Dallas, TX      Dallas, TX
# 6                     ClearOne Advantage    Baltimore, MD   Baltimore, MD
# 7                             Logic20/20     San Jose, CA     Seattle, WA
# 8              Rochester Regional Health    Rochester, NY   Rochester, NY
# 9                               <intent>     New York, NY    New York, NY
#
#                      Size  Founded   Type of ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2   501 to 1000 employees     2010   Company - Private
# 3  1001 to 5000 employees     1965          Government
# 4     51 to 200 employees     1998   Company - Private
# 5    201 to 500 employees     2000    Company - Public
# 6   501 to 1000 employees     2008   Company - Private
# 7    201 to 500 employees     2005   Company - Private
# 8        10000+ employees     2014            Hospital
# 9     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
# 5                  Digital Realty, CoreSite, Equinix        0         0
# 6                                                 -1        0         0
# 7                                                 -1        0         0
# 8                                                 -1        0         0
# 9                          Clicktripz, SmarterTravel        0         0
#
#    Min_Salary  Max_Salary State  Same State  Age
# 0          53          91    NM           0   50
# 1          63         112    MD           0   39
# 2          80          90    FL           1   13
# 3          56          97    WA           1   58
# 4          86         143    NY           1   25
# 5          71         119    TX           1   23
# 6          54          93    MD           1   15
# 7          86         142    CA           0   18
# 8          38          84    NY           1    9
# 9         120         160    NY           1   14

# %% [markdown]
# ## Parsing the Job Description (python etc)
#
# Lets Finds out the following the job description:
# - python.
# - R Studio.
# - Spark.
# - AWS.
# - Excel

# %%
# for python
df['Python_yn'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)

# %%
# R Studio
df['R Studio'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() or 'r_studio' in x.lower() else 0)

# %%
# For Spark
df['Spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)

# %%
# For AWS
df['AWS_yn'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)

# %%
# For Excel
df['Excel_yn'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)

# %%
df.head(10)
# Out:
#    Unnamed: 0                  Job Title  Salary Estimate  \
# 0           0             Data Scientist             72.0
# 1           1  Healthcare Data Scientist             87.5
# 2           2             Data Scientist             85.0
# 3           3             Data Scientist             76.5
# 4           4             Data Scientist            114.5
# 5           5             Data Scientist             95.0
# 6           6             Data Scientist             73.5
# 7           7             Data Scientist            114.0
# 8           8         Research Scientist             61.0
# 9           9             Data Scientist            140.0
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  CyrusOne is seeking a talented Data Scientist ...     3.4
# 6  Job Description\n\n**Please only local candida...     4.1
# 7  Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8  SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9  isn’t your usual company. Our work is powered ...     4.6
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# 3                                   PNNL     Richland, WA    Richland, WA
# 4                     Affinity Solutions     New York, NY    New York, NY
# 5                               CyrusOne       Dallas, TX      Dallas, TX
# 6                     ClearOne Advantage    Baltimore, MD   Baltimore, MD
# 7                             Logic20/20     San Jose, CA     Seattle, WA
# 8              Rochester Regional Health    Rochester, NY   Rochester, NY
# 9                               <intent>     New York, NY    New York, NY
#
#                      Size  Founded   Type of ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2   501 to 1000 employees     2010   Company - Private
# 3  1001 to 5000 employees     1965          Government
# 4     51 to 200 employees     1998   Company - Private
# 5    201 to 500 employees     2000    Company - Public
# 6   501 to 1000 employees     2008   Company - Private
# 7    201 to 500 employees     2005   Company - Private
# 8        10000+ employees     2014            Hospital
# 9     51 to 200 employees     2009   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
# 5                       Real Estate                   Real Estate
# 6             Banks & Credit Unions                       Finance
# 7                        Consulting             Business Services
# 8  Health Care Services & Hospitals                   Health Care
# 9                          Internet        Information Technology
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
# 5            $1 to $2 billion (USD)
# 6          Unknown / Non-Applicable
# 7          $25 to $50 million (USD)
# 8  $500 million to $1 billion (USD)
# 9        $100 to $500 million (USD)
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
# 5                  Digital Realty, CoreSite, Equinix        0         0
# 6                                                 -1        0         0
# 7                                                 -1        0         0
# 8                                                 -1        0         0
# 9                          Clicktripz, SmarterTravel        0         0
#
#    Min_Salary  Max_Salary State  Same State  Age  Python_yn  R Studio  Spark  \
# 0          53          91    NM           0   50          1         0      0
# 1          63         112    MD           0   39          1         0      0
# 2          80          90    FL           1   13          1         0      1
# 3          56          97    WA           1   58          1         0      0
# 4          86         143    NY           1   25          1         0      0
# 5          71         119    TX           1   23          1         0      0
# 6          54          93    MD           1   15          0         0      0
# 7          86         142    CA           0   18          1         0      1
# 8          38          84    NY           1    9          0         0      0
# 9         120         160    NY           1   14          1         0      1
#
#    AWS_yn  Excel_yn
# 0       0         1
# 1       0         0
# 2       0         1
# 3       0         0
# 4       0         1
# 5       1         1
# 6       0         1
# 7       1         1
# 8       0         0
# 9       0         0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'PerHour', 'Employee', 'Min_Salary', 'Max_Salary', 'State',
#        'Same State', 'Age', 'Python_yn', 'R Studio', 'Spark', 'AWS_yn',
#        'Excel_yn'],
#       dtype='object')

# %%
#df = df.drop(['Unnamed: 0'], axis=1)
# columns = df.columns
list = ['Job Title', 'Salary Estimate', 'Job Description',
       'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
       'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
       'PerHour', 'Employee', 'Min_Salary', 'Max_Salary', 'State',
       'Same State', 'Age', 'Python_yn', 'R Studio', 'Spark', 'AWS_yn',
       'Excel_yn']
# CleanedData= pd.DataFrame()
CleanedData=df[list]

# %%
CleanedData.head()
# Out:
#                    Job Title  Salary Estimate  \
# 0             Data Scientist             72.0
# 1  Healthcare Data Scientist             87.5
# 2             Data Scientist             85.0
# 3             Data Scientist             76.5
# 4             Data Scientist            114.5
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# 3                                   PNNL     Richland, WA    Richland, WA
# 4                     Affinity Solutions     New York, NY    New York, NY
#
#                      Size  Founded   Type of ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2   501 to 1000 employees     2010   Company - Private
# 3  1001 to 5000 employees     1965          Government
# 4     51 to 200 employees     1998   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
#
#                                          Competitors  PerHour  Employee  \
# 0                                                 -1        0         0
# 1                                                 -1        0         0
# 2                                                 -1        0         0
# 3  Oak Ridge National Laboratory, National Renewa...        0         0
# 4               Commerce Signals, Cardlytics, Yodlee        0         0
#
#    Min_Salary  Max_Salary State  Same State  Age  Python_yn  R Studio  Spark  \
# 0          53          91    NM           0   50          1         0      0
# 1          63         112    MD           0   39          1         0      0
# 2          80          90    FL           1   13          1         0      1
# 3          56          97    WA           1   58          1         0      0
# 4          86         143    NY           1   25          1         0      0
#
#    AWS_yn  Excel_yn
# 0       0         1
# 1       0         0
# 2       0         1
# 3       0         0
# 4       0         1

# %%
CleanedData.to_csv('Salary_Data_Cleaned.csv')
